# %% [markdown]
# Data were prepared by [this script](https://www.kaggle.com/aharless/preparing-data-for-lgbm-or-something-else/output).
#
# This is essentially a 2-step process to implement (Bojan's [retuning](https://www.kaggle.com/tunguz/lgbm-one-step-ahead-lb-0-514) of) [Lingzhi's upgraded version](https://www.kaggle.com/vrtjso/lgbm-one-step-ahead) of Ceshine's [LGBM starter](https://www.kaggle.com/ceshine/lgbm-starter) script.  The results are slightly different, probably because of lost precision (since I only use 6 decimal places in the prepared data) or maybe because there's a bug.
#
# This is an experiment with the new Kaggle feature that allows you to create kernels directly using the output of another kernel.   If you want to run variations on the model fit (or a completely different model using the same data setup), you don't have to prepare the data again every time.  Turns out it's pretty easy to [run a different kind of model](https://www.kaggle.com/aharless/nn-starter-using-lingzhi-data/) on the same data.

# %%
MAX_PRED=1000

# %%
from datetime import date, timedelta
import pandas as pd
import numpy as np
from sklearn.metrics import mean_squared_error
import lightgbm as lgb
from subprocess import check_output
print(check_output(["ls", "../input"]).decode("utf8"))
# Out:
# favorita-grocery-sales-forecasting
# preparing-data-for-lgbm-or-something-else

# %%
indir = '../input/preparing-data-for-lgbm-or-something-else/'
indir2 = '../input/favorita-grocery-sales-forecasting/'

# %%
X_test = pd.read_csv(indir + 'X_test.csv')
X_val = pd.read_csv(indir + 'X_val.csv')
X_train = pd.read_csv(indir + 'X_train.csv')
y_train = np.array(pd.read_csv(indir + 'y_train.csv'))
y_val = np.array(pd.read_csv(indir + 'y_val.csv'))
stores_items = pd.read_csv(indir + 'stores_items.csv', index_col=['store_nbr','item_nbr'])
test_ids = pd.read_csv( indir + 'test_ids.csv',  parse_dates=['date']).set_index(
                        ['store_nbr', 'item_nbr', 'date'] )

# %%
items = pd.read_csv( indir2 + 'items.csv' ).set_index("item_nbr")
items = items.reindex( stores_items.index.get_level_values(1) )

# %%
params = {
    'num_leaves': 31,
    'objective': 'regression',
    'min_data_in_leaf': 200,
    'learning_rate': 0.02,
    'feature_fraction': 0.8,
    'bagging_fraction': 0.8,
    'bagging_freq': 2,
    'metric': 'l2',
    'num_threads': 4
}

# %%
MAX_ROUNDS = 3000
val_pred = []
test_pred = []
cate_vars = []
for i in range(16):
    print("=" * 50)
    print("Step %d" % (i+1))
    print("=" * 50)
    dtrain = lgb.Dataset(
        X_train, label=y_train[:, i],
        categorical_feature=cate_vars,
        weight=pd.concat([items["perishable"]] * 6) * 0.25 + 1
    )
    dval = lgb.Dataset(
        X_val, label=y_val[:, i], reference=dtrain,
        weight=items["perishable"] * 0.25 + 1,
        categorical_feature=cate_vars)
    bst = lgb.train(
        params, dtrain, num_boost_round=MAX_ROUNDS,
        valid_sets=[dtrain, dval], early_stopping_rounds=125, verbose_eval=500
    )
    print("\n".join(("%s: %.2f" % x) for x in sorted(
        zip(X_train.columns, bst.feature_importance("gain")),
        key=lambda x: x[1], reverse=True
    )))
    val_pred.append(bst.predict(
        X_val, num_iteration=bst.best_iteration or MAX_ROUNDS))
    test_pred.append(bst.predict(
        X_test, num_iteration=bst.best_iteration or MAX_ROUNDS))
# Out:
# ==================================================
# Step 1
# ==================================================
# /opt/conda/lib/python3.6/site-packages/lightgbm/basic.py:1030: UserWarning: Using categorical_feature in Dataset.
#   warnings.warn('Using categorical_feature in Dataset.')
# Training until validation scores don't improve for 125 rounds.
# [500]	training's l2: 0.301319	valid_1's l2: 0.29358
# [1000]	training's l2: 0.297485	valid_1's l2: 0.292137
# [1500]	training's l2: 0.294849	valid_1's l2: 0.291689
# [2000]	training's l2: 0.292608	valid_1's l2: 0.291455
# [2500]	training's l2: 0.29059	valid_1's l2: 0.291284
# [3000]	training's l2: 0.288713	valid_1's l2: 0.291182
# mean_7_2017: 8837494.87
# mean_14_2017: 5724666.77
# mean_30_2017: 730472.62
# promo_0: 510501.74
# day_1_2017: 430153.05
# mean_3_2017: 419690.21
# mean_20_dow0_2017: 419304.59
# mean_4_dow0_2017: 275115.89
# promo_14_2017: 136050.21
# mean_60_2017: 118814.88
# mean_4_dow5_2017: 41869.78
# promo_7: 39819.89
# mean_140_2017: 37296.20
# promo_60_2017: 34707.96
# promo_140_2017: 31761.05
# mean_4_dow6_2017: 29343.16
# mean_20_dow4_2017: 28911.88
# mean_4_dow2_2017: 25342.88
# mean_20_dow2_2017: 23826.37
# mean_20_dow1_2017: 16954.39
# mean_4_dow1_2017: 16533.90
# promo_14: 16274.59
# mean_4_dow4_2017: 16187.63
# mean_20_dow3_2017: 15631.91
# mean_4_dow3_2017: 15513.47
# mean_20_dow6_2017: 14236.93
# mean_20_dow5_2017: 12721.51
# promo_9: 12417.97
# promo_15: 7575.71
# promo_1: 5565.23
# promo_13: 5533.67
# promo_11: 5453.49
# promo_3: 4970.24
# promo_2: 4564.77
# promo_4: 4274.66
# promo_12: 2917.67
# promo_10: 2477.39
# promo_6: 1793.03
# promo_5: 1383.34
# promo_8: 881.59
# ==================================================
# Step 2
# ==================================================
# Training until validation scores don't improve for 125 rounds.
# [500]	training's l2: 0.325964	valid_1's l2: 0.326846
# [1000]	training's l2: 0.322143	valid_1's l2: 0.325574
# [1500]	training's l2: 0.319322	valid_1's l2: 0.324977
# [2000]	training's l2: 0.316907	valid_1's l2: 0.324701
# [2500]	training's l2: 0.314662	valid_1's l2: 0.32451
# Early stopping, best iteration is:
# [2440]	training's l2: 0.31492	valid_1's l2: 0.324493
# mean_14_2017: 6628438.11
# mean_7_2017: 5172570.49
# mean_30_2017: 1409178.20
# mean_20_dow1_2017: 352650.38
# promo_1: 304586.81
# mean_60_2017: 266616.07
# day_1_2017: 179481.89
# mean_3_2017: 120760.43
# promo_14_2017: 115527.45
# mean_4_dow1_2017: 92253.52
# mean_140_2017: 34776.73
# mean_20_dow2_2017: 31369.69
# promo_60_2017: 28552.77
# mean_20_dow4_2017: 26593.51
# promo_0: 24534.90
# promo_140_2017: 21929.69
# mean_4_dow2_2017: 21096.36
# mean_4_dow6_2017: 18562.11
# mean_4_dow0_2017: 17622.76
# mean_4_dow4_2017: 16063.76
# mean_4_dow5_2017: 15275.45
# promo_3: 15229.19
# mean_4_dow3_2017: 15070.08
# mean_20_dow0_2017: 14912.11
# mean_20_dow6_2017: 13972.62
# promo_4: 13579.38
# mean_20_dow5_2017: 13150.23
# mean_20_dow3_2017: 11200.27
# promo_2: 8006.13
# promo_5: 6473.92
# promo_7: 4421.40
# promo_6: 4362.55
# promo_14: 2549.90
# promo_11: 2157.07
# promo_15: 1843.27
# promo_13: 1545.76
# promo_10: 1363.61
# promo_9: 1336.58
# promo_8: 991.31
# promo_12: 660.72
# ==================================================
# Step 3
# ==================================================
# Training until validation scores don't improve for 125 rounds.
# [500]	training's l2: 0.328505	valid_1's l2: 0.340442
# [1000]	training's l2: 0.323971	valid_1's l2: 0.338997
# [1500]	training's l2: 0.320834	valid_1's l2: 0.338379
# [2000]	training's l2: 0.318226	valid_1's l2: 0.338051
# [2500]	training's l2: 0.315871	valid_1's l2: 0.337872
# Early stopping, best iteration is:
# [2809]	training's l2: 0.314502	valid_1's l2: 0.337753
# mean_14_2017: 8100685.02
# mean_7_2017: 4696190.83
# mean_30_2017: 1299352.88
# mean_4_dow2_2017: 1111277.14
# mean_20_dow2_2017: 1073155.13
# promo_2: 472240.21
# mean_60_2017: 131328.54
# promo_14_2017: 130742.02
# mean_3_2017: 97481.82
# day_1_2017: 61195.77
# promo_140_2017: 55595.19
# promo_60_2017: 42455.06
# mean_20_dow4_2017: 37907.44
# promo_3: 32457.96
# mean_4_dow1_2017: 30482.56
# promo_9: 29870.72
# mean_4_dow0_2017: 26341.80
# mean_4_dow3_2017: 25970.31
# mean_20_dow5_2017: 24250.15
# mean_20_dow1_2017: 23680.89
# promo_0: 21242.66
# mean_140_2017: 19100.86
# promo_4: 18203.26
# promo_5: 17386.08
# mean_4_dow6_2017: 17328.01
# mean_4_dow4_2017: 17260.73
# mean_20_dow0_2017: 16874.85
# promo_7: 16605.14
# mean_20_dow3_2017: 16031.78
# mean_4_dow5_2017: 15493.01
# mean_20_dow6_2017: 14796.61
# promo_11: 7852.59
# promo_1: 7770.76
# promo_14: 7202.15
# promo_15: 6647.67
# promo_6: 5731.40
# promo_10: 4846.52
# promo_13: 3128.31
# promo_8: 2546.60
# promo_12: 2537.74
# ==================================================
# Step 4
# ==================================================
# Training until validation scores don't improve for 125 rounds.
# [500]	training's l2: 0.351825	valid_1's l2: 0.353886
# [1000]	training's l2: 0.346974	valid_1's l2: 0.352366
# [1500]	training's l2: 0.343604	valid_1's l2: 0.351852
# [2000]	training's l2: 0.340866	valid_1's l2: 0.35156
# [2500]	training's l2: 0.338437	valid_1's l2: 0.351523
# Early stopping, best iteration is:
# [2419]	training's l2: 0.338818	valid_1's l2: 0.351507
# mean_14_2017: 9874953.15
# mean_7_2017: 3560650.51
# mean_30_2017: 3125986.39
# mean_4_dow3_2017: 1067894.34
# mean_20_dow3_2017: 826384.33
# mean_60_2017: 520842.32
# promo_3: 352166.05
# mean_3_2017: 268006.84
# mean_4_dow4_2017: 106888.07
# promo_14_2017: 100200.81
# day_1_2017: 41101.55
# promo_140_2017: 36934.77
# promo_60_2017: 36456.25
# mean_140_2017: 31846.26
# promo_5: 29396.32
# mean_4_dow2_2017: 25462.89
# promo_4: 25383.90
# mean_20_dow5_2017: 23520.49
# mean_20_dow0_2017: 22124.62
# promo_7: 22031.58
# mean_4_dow0_2017: 20778.64
# mean_20_dow4_2017: 19907.79
# mean_20_dow6_2017: 19592.65
# promo_2: 19091.20
# mean_20_dow2_2017: 16931.64
# mean_4_dow6_2017: 15029.61
# mean_4_dow1_2017: 14942.77
# promo_0: 14638.55
# mean_4_dow5_2017: 14477.60
# mean_20_dow1_2017: 13821.71
# promo_6: 12236.52
# promo_1: 9795.95
# promo_14: 6284.06
# promo_9: 3904.86
# promo_8: 3421.68
# promo_10: 3022.76
# promo_15: 2605.11
# promo_13: 2114.42
# promo_11: 1301.35
# promo_12: 1199.84
# ==================================================
# Step 5
# ==================================================
# Training until validation scores don't improve for 125 rounds.
# [500]	training's l2: 0.362293	valid_1's l2: 0.35705
# [1000]	training's l2: 0.356832	valid_1's l2: 0.35518
# [1500]	training's l2: 0.353128	valid_1's l2: 0.354594
# [2000]	training's l2: 0.350003	valid_1's l2: 0.354327
# Early stopping, best iteration is:
# [1989]	training's l2: 0.350061	valid_1's l2: 0.354321
# mean_14_2017: 7007139.62
# mean_4_dow4_2017: 5768503.34
# mean_7_2017: 3000153.13
# mean_30_2017: 1811783.75
# mean_3_2017: 1407768.44
# mean_20_dow4_2017: 1313327.95
# promo_4: 355208.81
# mean_60_2017: 245183.73
# promo_14_2017: 93631.38
# mean_4_dow3_2017: 82400.10
# promo_3: 37813.28
# promo_60_2017: 37323.97
# promo_140_2017: 34861.11
# promo_7: 34466.38
# promo_5: 34072.40
# day_1_2017: 29792.93
# mean_20_dow0_2017: 24222.62
# mean_20_dow1_2017: 23455.06
# mean_140_2017: 22625.12
# promo_2: 21488.40
# mean_20_dow2_2017: 20799.32
# promo_0: 18087.66
# promo_6: 17617.36
# mean_4_dow0_2017: 17023.44
# mean_20_dow3_2017: 16081.95
# mean_4_dow5_2017: 13820.79
# mean_20_dow6_2017: 13539.10
# mean_4_dow2_2017: 13142.74
# mean_4_dow6_2017: 13089.58
# promo_1: 12125.18
# mean_20_dow5_2017: 10926.64
# mean_4_dow1_2017: 10519.13
# promo_11: 10373.85
# promo_14: 8257.08
# promo_9: 5879.98
# promo_10: 4669.88
# promo_13: 3728.51
# promo_15: 3685.46
# promo_8: 3052.74
# promo_12: 2760.33
# ==================================================
# Step 6
# ==================================================
# Training until validation scores don't improve for 125 rounds.
# [500]	training's l2: 0.355297	valid_1's l2: 0.360662
# [1000]	training's l2: 0.350703	valid_1's l2: 0.359293
# [1500]	training's l2: 0.347495	valid_1's l2: 0.358886
# Early stopping, best iteration is:
# [1742]	training's l2: 0.346089	valid_1's l2: 0.358748
# mean_14_2017: 6343326.05
# mean_30_2017: 5060915.72
# mean_7_2017: 1687729.53
# mean_3_2017: 1253162.18
# mean_60_2017: 791610.01
# mean_20_dow5_2017: 406756.62
# mean_4_dow5_2017: 404290.07
# promo_5: 382070.42
# promo_14_2017: 97948.75
# promo_3: 54210.06
# mean_4_dow6_2017: 45101.50
# promo_7: 39057.76
# mean_20_dow6_2017: 38151.54
# day_1_2017: 35389.11
# promo_60_2017: 34506.72
# mean_140_2017: 32828.29
# promo_6: 30682.16
# promo_140_2017: 24098.69
# mean_20_dow0_2017: 18602.51
# mean_20_dow3_2017: 17700.54
# mean_4_dow0_2017: 16897.87
# mean_20_dow2_2017: 13936.49
# promo_4: 13895.58
# mean_4_dow2_2017: 13791.10
# mean_4_dow1_2017: 13348.54
# mean_4_dow4_2017: 12740.42
# mean_4_dow3_2017: 12740.21
# mean_20_dow1_2017: 12294.63
# promo_2: 12279.86
# mean_20_dow4_2017: 12004.81
# promo_0: 11833.46
# promo_9: 8664.86
# promo_1: 7222.41
# promo_14: 5652.38
# promo_13: 5317.45
# promo_8: 4778.02
# promo_11: 4177.99
# promo_12: 3453.54
# promo_10: 3305.42
# promo_15: 2441.36
# ==================================================
# Step 7
# ==================================================
# Training until validation scores don't improve for 125 rounds.
# [500]	training's l2: 0.34553	valid_1's l2: 0.421344
# [1000]	training's l2: 0.341057	valid_1's l2: 0.420651
# [1500]	training's l2: 0.337839	valid_1's l2: 0.420295
# [2000]	training's l2: 0.335254	valid_1's l2: 0.420182
# Early stopping, best iteration is:
# [1963]	training's l2: 0.335435	valid_1's l2: 0.420151
# mean_14_2017: 5857567.99
# mean_30_2017: 4287618.06
# mean_7_2017: 1941413.42
# mean_3_2017: 806848.52
# mean_20_dow6_2017: 778459.14
# mean_60_2017: 646814.11
# promo_6: 605479.70
# mean_4_dow6_2017: 587346.99
# promo_14_2017: 104763.10
# day_1_2017: 73925.26
# promo_3: 54897.14
# promo_7: 47388.45
# mean_4_dow5_2017: 42530.81
# mean_20_dow5_2017: 40014.04
# mean_140_2017: 38687.54
# promo_60_2017: 35614.63
# promo_140_2017: 29949.91
# promo_5: 27769.04
# mean_20_dow1_2017: 27010.73
# promo_13: 23469.74
# mean_4_dow1_2017: 19451.33
# mean_20_dow0_2017: 19184.79
# mean_4_dow0_2017: 19179.34
# mean_20_dow3_2017: 16010.01
# promo_0: 15226.86
# promo_4: 14522.98
# mean_4_dow2_2017: 14207.16
# mean_20_dow4_2017: 14187.34
# mean_4_dow3_2017: 13418.23
# mean_20_dow2_2017: 13027.73
# mean_4_dow4_2017: 12373.10
# promo_9: 10616.87
# promo_14: 10546.12
# promo_2: 8325.17
# promo_15: 7460.95
# promo_1: 7063.87
# promo_8: 3254.82
# promo_11: 3040.30
# promo_10: 2195.95
# promo_12: 2066.02
# ==================================================
# Step 8
# ==================================================
# Training until validation scores don't improve for 125 rounds.
# [500]	training's l2: 0.331933	valid_1's l2: 0.389298
# [1000]	training's l2: 0.327351	valid_1's l2: 0.388291
# Early stopping, best iteration is:
# [1002]	training's l2: 0.327342	valid_1's l2: 0.38829
# mean_14_2017: 5816195.74
# mean_30_2017: 4502804.14
# mean_7_2017: 3212314.40
# mean_20_dow0_2017: 890754.30
# promo_7: 837125.46
# mean_60_2017: 546133.05
# mean_4_dow0_2017: 351917.01
# promo_0: 119126.11
# mean_3_2017: 110019.57
# day_1_2017: 82095.08
# promo_14_2017: 66277.66
# promo_14: 54086.42
# promo_60_2017: 51070.15
# promo_140_2017: 44417.90
# mean_140_2017: 39319.06
# promo_3: 26448.92
# mean_20_dow2_2017: 24740.84
# mean_20_dow4_2017: 22072.83
# mean_4_dow5_2017: 18216.99
# promo_6: 17544.01
# promo_5: 16935.92
# mean_4_dow6_2017: 12033.50
# promo_9: 11176.53
# mean_20_dow1_2017: 10952.28
# mean_20_dow3_2017: 10007.24
# mean_4_dow2_2017: 9423.69
# promo_15: 8948.76
# mean_20_dow6_2017: 8758.36
# promo_4: 8316.39
# mean_4_dow1_2017: 8167.42
# promo_2: 7339.22
# promo_8: 7086.06
# mean_4_dow3_2017: 6988.22
# promo_10: 6250.93
# mean_4_dow4_2017: 6220.82
# mean_20_dow5_2017: 6100.89
# promo_11: 4465.07
# promo_13: 3923.37
# promo_1: 2509.29
# promo_12: 1830.88
# ==================================================
# Step 9
# ==================================================
# Training until validation scores don't improve for 125 rounds.
# [500]	training's l2: 0.34139	valid_1's l2: 0.380124
# [1000]	training's l2: 0.337192	valid_1's l2: 0.37926
# [1500]	training's l2: 0.334071	valid_1's l2: 0.378929
# Early stopping, best iteration is:
# [1703]	training's l2: 0.333006	valid_1's l2: 0.378811
# mean_30_2017: 4964913.89
# mean_14_2017: 3745830.46
# mean_7_2017: 2311753.99
# mean_60_2017: 1245127.61
# mean_20_dow1_2017: 544302.81
# promo_8: 537905.85
# mean_4_dow1_2017: 107250.36
# promo_14_2017: 89712.75
# day_1_2017: 89064.05
# mean_3_2017: 53999.15
# promo_10: 52885.89
# promo_60_2017: 48516.00
# mean_20_dow2_2017: 45959.90
# promo_7: 40800.38
# mean_140_2017: 33158.01
# promo_140_2017: 28357.52
# mean_20_dow4_2017: 25430.00
# promo_12: 18391.95
# promo_11: 18388.23
# mean_4_dow0_2017: 18347.52
# mean_4_dow2_2017: 16716.36
# mean_20_dow0_2017: 16246.87
# promo_9: 15449.14
# mean_4_dow6_2017: 15041.82
# mean_20_dow6_2017: 13961.92
# mean_4_dow5_2017: 11783.98
# promo_0: 11128.71
# mean_4_dow3_2017: 11116.47
# mean_4_dow4_2017: 10814.06
# mean_20_dow5_2017: 10624.84
# promo_13: 10023.93
# mean_20_dow3_2017: 9773.40
# promo_14: 9762.68
# promo_3: 7297.07
# promo_6: 6457.84
# promo_4: 4202.55
# promo_2: 3506.83
# promo_15: 3065.49
# promo_1: 2465.81
# promo_5: 2341.98
# ==================================================
# Step 10
# ==================================================
# Training until validation scores don't improve for 125 rounds.
# [500]	training's l2: 0.345248	valid_1's l2: 0.368786
# [1000]	training's l2: 0.340394	valid_1's l2: 0.367568
# [1500]	training's l2: 0.336999	valid_1's l2: 0.367054
# [2000]	training's l2: 0.334162	valid_1's l2: 0.366767
# Early stopping, best iteration is:
# [1998]	training's l2: 0.334171	valid_1's l2: 0.366763
# mean_14_2017: 4440410.81
# mean_30_2017: 4353606.72
# mean_7_2017: 2552308.36
# mean_20_dow2_2017: 1771058.95
# mean_4_dow2_2017: 1725280.57
# promo_9: 648977.05
# mean_60_2017: 521872.53
# promo_14_2017: 111674.90
# promo_140_2017: 66846.60
# promo_2: 59992.64
# mean_3_2017: 58134.10
# promo_10: 50929.54
# promo_60_2017: 47493.82
# day_1_2017: 39979.35
# promo_7: 39753.95
# mean_20_dow4_2017: 37250.32
# mean_20_dow1_2017: 36180.54
# mean_4_dow1_2017: 33584.21
# promo_14: 28148.05
# promo_8: 24451.18
# mean_4_dow0_2017: 21435.56
# mean_20_dow5_2017: 20733.38
# mean_20_dow0_2017: 19754.71
# mean_4_dow3_2017: 18893.72
# promo_12: 18454.66
# promo_11: 17971.65
# mean_140_2017: 15577.42
# mean_20_dow3_2017: 14678.44
# mean_20_dow6_2017: 13690.89
# mean_4_dow5_2017: 12879.30
# mean_4_dow4_2017: 12346.54
# mean_4_dow6_2017: 12140.88
# promo_13: 11923.21
# promo_0: 7233.44
# promo_6: 5267.27
# promo_1: 5054.79
# promo_4: 4573.20
# promo_15: 3781.43
# promo_3: 2105.62
# promo_5: 1578.13
# ==================================================
# Step 11
# ==================================================
# Training until validation scores don't improve for 125 rounds.
# [500]	training's l2: 0.37366	valid_1's l2: 0.373833
# [1000]	training's l2: 0.368173	valid_1's l2: 0.37238
# [1500]	training's l2: 0.364452	valid_1's l2: 0.371929
# Early stopping, best iteration is:
# [1595]	training's l2: 0.36382	valid_1's l2: 0.37191
# mean_30_2017: 6737045.68
# mean_14_2017: 4119940.11
# mean_7_2017: 2991064.92
# mean_60_2017: 2036261.18
# mean_4_dow3_2017: 1250695.33
# mean_20_dow3_2017: 821141.16
# promo_10: 499666.14
# mean_3_2017: 105276.49
# promo_14_2017: 84861.64
# mean_4_dow4_2017: 71052.36
# mean_4_dow2_2017: 53609.01
# promo_60_2017: 46247.75
# promo_140_2017: 39345.94
# promo_14: 35309.83
# mean_140_2017: 33905.60
# promo_7: 32551.56
# promo_9: 30960.09
# promo_11: 28067.79
# promo_12: 26394.92
# day_1_2017: 25632.84
# mean_20_dow5_2017: 23185.56
# mean_20_dow2_2017: 21660.34
# mean_20_dow0_2017: 21506.73
# promo_8: 21415.27
# promo_13: 20307.41
# mean_20_dow4_2017: 18296.93
# mean_20_dow6_2017: 17985.11
# mean_4_dow0_2017: 16146.16
# mean_20_dow1_2017: 13915.75
# mean_4_dow1_2017: 10874.22
# mean_4_dow6_2017: 10551.05
# mean_4_dow5_2017: 10449.23
# promo_3: 10021.22
# promo_0: 7000.83
# promo_6: 6149.08
# promo_15: 5301.20
# promo_4: 3773.24
# promo_2: 3152.89
# promo_5: 2335.60
# promo_1: 1835.67
# ==================================================
# Step 12
# ==================================================
# Training until validation scores don't improve for 125 rounds.
# [500]	training's l2: 0.383646	valid_1's l2: 0.385736
# [1000]	training's l2: 0.378	valid_1's l2: 0.384181
# [1500]	training's l2: 0.373901	valid_1's l2: 0.383706
# [2000]	training's l2: 0.370652	valid_1's l2: 0.383518
# Early stopping, best iteration is:
# [2370]	training's l2: 0.368487	valid_1's l2: 0.38346
# mean_4_dow4_2017: 6957569.60
# mean_30_2017: 4990797.79
# mean_14_2017: 3255368.39
# mean_20_dow4_2017: 1298933.32
# mean_7_2017: 1031601.38
# mean_60_2017: 1018188.54
# mean_3_2017: 728740.67
# promo_11: 470199.86
# mean_4_dow3_2017: 102787.63
# promo_14_2017: 84122.22
# promo_12: 72956.67
# promo_14: 58436.89
# promo_140_2017: 48318.51
# mean_140_2017: 43066.86
# promo_60_2017: 40888.84
# promo_13: 33300.08
# promo_9: 32686.96
# promo_10: 31695.43
# day_1_2017: 26854.96
# mean_20_dow0_2017: 26338.39
# promo_4: 25418.74
# mean_20_dow3_2017: 24969.20
# mean_20_dow1_2017: 24257.46
# promo_7: 23580.06
# mean_20_dow6_2017: 21626.30
# mean_20_dow2_2017: 21523.85
# mean_4_dow0_2017: 20437.41
# mean_20_dow5_2017: 18950.43
# promo_8: 17834.31
# mean_4_dow5_2017: 15718.00
# mean_4_dow6_2017: 15700.21
# mean_4_dow1_2017: 15544.65
# mean_4_dow2_2017: 15119.21
# promo_0: 8389.72
# promo_15: 7674.82
# promo_6: 6059.93
# promo_2: 4565.09
# promo_3: 3292.88
# promo_1: 3141.17
# promo_5: 2082.73
# ==================================================
# Step 13
# ==================================================
# Training until validation scores don't improve for 125 rounds.
# [500]	training's l2: 0.369606	valid_1's l2: 0.376485
# [1000]	training's l2: 0.364612	valid_1's l2: 0.375657
# Early stopping, best iteration is:
# [1271]	training's l2: 0.36258	valid_1's l2: 0.375479
# mean_30_2017: 6986011.60
# mean_14_2017: 3192199.14
# mean_60_2017: 1911000.95
# mean_7_2017: 1441183.55
# mean_3_2017: 822485.63
# promo_12: 495231.95
# mean_20_dow5_2017: 441768.88
# mean_4_dow5_2017: 420205.77
# promo_14_2017: 80087.24
# promo_13: 65093.31
# promo_14: 58609.56
# promo_10: 50955.93
# mean_140_2017: 47624.79
# promo_60_2017: 39932.19
# day_1_2017: 39262.26
# mean_20_dow0_2017: 35656.64
# promo_140_2017: 28731.06
# mean_20_dow6_2017: 26092.76
# mean_4_dow6_2017: 18131.95
# mean_4_dow0_2017: 17126.23
# promo_9: 17002.89
# promo_11: 16798.08
# mean_20_dow3_2017: 16424.73
# mean_20_dow2_2017: 14431.62
# promo_15: 12949.57
# mean_20_dow1_2017: 11882.82
# promo_7: 11381.25
# mean_4_dow2_2017: 10994.80
# mean_20_dow4_2017: 10492.68
# mean_4_dow1_2017: 9823.74
# mean_4_dow4_2017: 9666.50
# mean_4_dow3_2017: 9432.48
# promo_8: 9339.14
# promo_0: 8309.72
# promo_5: 6383.32
# promo_6: 4841.90
# promo_3: 3596.04
# promo_2: 3348.64
# promo_4: 2726.44
# promo_1: 1769.47
# ==================================================
# Step 14
# ==================================================
# Training until validation scores don't improve for 125 rounds.
# [500]	training's l2: 0.358869	valid_1's l2: 0.361812
# [1000]	training's l2: 0.354304	valid_1's l2: 0.360884
# [1500]	training's l2: 0.350958	valid_1's l2: 0.360709
# [2000]	training's l2: 0.348116	valid_1's l2: 0.36059
# Early stopping, best iteration is:
# [1936]	training's l2: 0.348449	valid_1's l2: 0.360572
# mean_30_2017: 6703951.24
# mean_14_2017: 2508939.30
# mean_7_2017: 1672922.77
# mean_60_2017: 1385338.64
# mean_20_dow6_2017: 1025333.88
# promo_13: 747418.62
# mean_3_2017: 480326.18
# mean_4_dow6_2017: 394440.54
# day_1_2017: 103975.18
# promo_14_2017: 84374.44
# mean_140_2017: 63383.99
# promo_14: 59305.55
# mean_4_dow5_2017: 51279.30
# mean_20_dow5_2017: 46127.85
# promo_10: 44969.06
# mean_20_dow1_2017: 44061.18
# promo_60_2017: 43785.60
# promo_140_2017: 38386.28
# promo_12: 33453.92
# promo_6: 30592.59
# mean_20_dow0_2017: 28253.26
# mean_4_dow1_2017: 20070.17
# mean_4_dow0_2017: 18081.34
# mean_20_dow3_2017: 17658.30
# mean_20_dow4_2017: 15568.69
# promo_0: 14962.97
# mean_20_dow2_2017: 14826.38
# mean_4_dow3_2017: 14065.05
# promo_9: 13844.80
# mean_4_dow2_2017: 13580.45
# promo_11: 13547.10
# mean_4_dow4_2017: 12573.06
# promo_15: 12061.22
# promo_7: 9754.89
# promo_8: 8280.92
# promo_2: 5030.25
# promo_4: 3393.73
# promo_1: 2747.64
# promo_3: 2697.28
# promo_5: 1712.27
# ==================================================
# Step 15
# ==================================================
# Training until validation scores don't improve for 125 rounds.
# [500]	training's l2: 0.34603	valid_1's l2: 0.348322
# [1000]	training's l2: 0.341322	valid_1's l2: 0.347076
# [1500]	training's l2: 0.338069	valid_1's l2: 0.346875
# [2000]	training's l2: 0.335289	valid_1's l2: 0.346706
# [2500]	training's l2: 0.332833	valid_1's l2: 0.346649
# [3000]	training's l2: 0.330578	valid_1's l2: 0.346526
# mean_30_2017: 6853639.97
# mean_14_2017: 3211403.06
# mean_7_2017: 2148511.44
# mean_20_dow0_2017: 1227309.05
# mean_60_2017: 1037855.79
# promo_14: 949605.95
# mean_4_dow0_2017: 304858.15
# promo_14_2017: 87324.45
# mean_3_2017: 81973.38
# day_1_2017: 81081.97
# promo_7: 75526.29
# promo_140_2017: 67984.09
# promo_0: 66483.26
# promo_60_2017: 56754.01
# mean_20_dow2_2017: 56460.84
# mean_140_2017: 51875.79
# promo_13: 44795.44
# mean_20_dow4_2017: 33453.77
# mean_4_dow2_2017: 30960.36
# promo_12: 29193.14
# mean_20_dow1_2017: 27791.74
# mean_4_dow5_2017: 24191.76
# promo_10: 24023.88
# mean_4_dow6_2017: 22626.85
# mean_20_dow6_2017: 21679.06
# mean_4_dow1_2017: 21004.78
# mean_20_dow3_2017: 20893.69
# promo_15: 18225.45
# mean_4_dow3_2017: 18155.36
# mean_4_dow4_2017: 18105.48
# mean_20_dow5_2017: 17875.68
# promo_9: 16906.58
# promo_2: 10788.20
# promo_11: 9551.48
# promo_6: 7782.72
# promo_4: 5781.76
# promo_8: 5733.25
# promo_1: 3508.68
# promo_5: 2491.41
# promo_3: 2241.01
# ==================================================
# Step 16
# ==================================================
# Training until validation scores don't improve for 125 rounds.
# [500]	training's l2: 0.356795	valid_1's l2: 0.37192
# [1000]	training's l2: 0.352378	valid_1's l2: 0.370668
# [1500]	training's l2: 0.34916	valid_1's l2: 0.370359
# Early stopping, best iteration is:
# [1721]	training's l2: 0.347897	valid_1's l2: 0.370207
# mean_30_2017: 6389289.99
# mean_14_2017: 2632227.00
# mean_60_2017: 1810438.69
# mean_7_2017: 985214.05
# mean_20_dow1_2017: 724261.08
# promo_15: 621821.24
# mean_4_dow1_2017: 99725.22
# mean_20_dow2_2017: 83015.69
# day_1_2017: 69548.56
# promo_14_2017: 66130.86
# promo_60_2017: 53904.07
# mean_140_2017: 53890.22
# promo_14: 52420.67
# mean_3_2017: 47772.35
# promo_140_2017: 39471.82
# mean_20_dow4_2017: 26760.13
# mean_20_dow0_2017: 20214.72
# mean_4_dow0_2017: 16366.19
# promo_10: 16358.49
# promo_13: 15852.22
# mean_4_dow2_2017: 14977.19
# mean_4_dow6_2017: 14586.49
# mean_20_dow6_2017: 14249.41
# mean_4_dow3_2017: 12474.23
# mean_4_dow4_2017: 11788.93
# mean_20_dow5_2017: 11602.21
# mean_20_dow3_2017: 11500.53
# mean_4_dow5_2017: 11324.75
# promo_12: 10850.96
# promo_7: 8442.84
# promo_0: 7628.58
# promo_9: 7130.95
# promo_8: 5832.92
# promo_11: 5445.57
# promo_6: 4289.36
# promo_1: 3227.26
# promo_2: 3142.48
# promo_4: 3068.54
# promo_3: 3055.96
# promo_5: 2096.06

# %%
n_public = 5 # Number of days in public test set
weights=pd.concat([items["perishable"]]) * 0.25 + 1
print("Unweighted validation mse: ", mean_squared_error(
    y_val, np.minimum( np.array(val_pred).transpose(), np.log1p(MAX_PRED) ) )   )
mse = mean_squared_error(
    y_val, np.minimum( np.array(val_pred).transpose(), np.log1p(MAX_PRED) ), 
    sample_weight=weights)
print("Full validation mse:       ", mse )
msepub = mean_squared_error(
    y_val[:,:n_public], 
    np.minimum( np.array(val_pred).transpose()[:,:n_public], np.log1p(MAX_PRED) ),
    sample_weight=weights)
print("'Public' validation mse:   ",  msepub )
msepriv = mean_squared_error(
    y_val[:,n_public:], 
    np.minimum( np.array(val_pred).transpose()[:,n_public:], np.log1p(MAX_PRED) ),
    sample_weight=weights)
print("'Private' validation mse:  ",  msepriv )
print('Validation NRMSWLE')
print( "  Full:    ", np.sqrt(mse) )
print( "  Public:  ", np.sqrt(msepub) )
print( "  Private: ", np.sqrt(msepriv) )
# Out:
# Unweighted validation mse:  0.361791131762
# Full validation mse:        0.361260891897
# 'Public' validation mse:    0.331851350717
# 'Private' validation mse:   0.37462886516
# Validation NRMSWLE
#   Full:     0.601049824804
#   Public:   0.576065404895
#   Private:  0.612069330354

# %%
y_test = np.array(test_pred).transpose()
df_preds = pd.DataFrame(
    y_test, index=stores_items.index,
    columns=pd.date_range("2017-08-16", periods=16)
).stack().to_frame("unit_sales")
df_preds.index.set_names(["store_nbr", "item_nbr", "date"], inplace=True)

# %%
submission = test_ids.join(df_preds, how="left").fillna(0)
submission["unit_sales"] = np.clip(np.expm1(submission["unit_sales"]), 0, MAX_PRED)
submission.to_csv('lgb_whatever.csv', float_format='%.4f', index=None)
