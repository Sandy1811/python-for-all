# %%
print("Sandeep")
# Out:
# Sandeep

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
name = str(input("What is your name?"))

print("Waw great! You have a beautiful name %s" % str(name))
# Out:
# What is your name? Sandeep
# Waw great! You have a beautiful name Sandeep

# %%
print("Sandeep")
# Out:
# Sandeep
